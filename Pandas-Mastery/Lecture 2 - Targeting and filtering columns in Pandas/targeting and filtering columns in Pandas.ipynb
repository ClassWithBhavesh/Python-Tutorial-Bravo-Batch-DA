# %% [markdown]
# ### ***Targeting Specific or Multiple Column in Pandas***

# %%
import pandas as pd

# %%
std_marks_df = pd.DataFrame({
    "stdName": ["Mohit", "Ronit", "Rohit", "Sonit"],
    "stdClass": ["X", "X", "XII", "XII"],
    "stdMarks": [98, 96, 63, 62]
})

std_marks_df
# Out:
#   stdName stdClass  stdMarks
# 0   Mohit        X        98
# 1   Ronit        X        96
# 2   Rohit      XII        63
# 3   Sonit      XII        62

# %%
# To target the specific column in pandas df -
# syntax - dataframeName['coulumnName']

# std_marks_df['stdName']   # targeting a specific column (series) form a df
# std_marks_df['stdMarks']


# Targeting multiple columns at once -
# std_marks_df[['stdClass', 'stdName']]
# newDf = std_marks_df[['stdClass', 'stdName', 'stdMarks']]
# newDf
# Out:
#   stdClass stdName  stdMarks
# 0        X   Mohit        98
# 1        X   Ronit        96
# 2      XII   Rohit        63
# 3      XII   Sonit        62

# %% [markdown]
# # ***Filtering DF using Pandas***

# %%
# std_marks_df[std_marks_df['stdMarks'] > 95]

# std_marks_df


# std_marks_df[std_marks_df['stdClass'] == 'XII']

# std_marks_df[(std_marks_df['stdMarks'] > 97) & (std_marks_df['stdClass'] == 'X')]
# Out:
#   stdName stdClass  stdMarks
# 0   Mohit        X        98
# 1   Ronit        X        96

# %% [markdown]
# # ***Adding or Inserting a new column in DataFrame***

# %%
# std_marks_df['stdGrades'] = (std_marks_df['stdMarks'] > 95) = "A" | (std_marks_df['stdMarks'] > 60) = "B"
# Out:
#   stdName stdClass  stdMarks stdGrades
# 0   Mohit        X        98         A
# 1   Ronit        X        96         A
# 2   Rohit      XII        63         B
# 3   Sonit      XII        62         B

# %%
std_marks_df
# Out:
#   stdName stdClass  stdMarks stdGrades
# 0   Mohit        X        98         A
# 1   Ronit        X        96         A
# 2   Rohit      XII        63         B
# 3   Sonit      XII        62         B

# %%
# std_marks_df.insert(posi(ind of column), 'columnName', 'coulmnValue')

# std_marks_df.insert(1, 'stdAge', [15,15,17,17])
# std_marks_df
# Out:
#   stdName  stdAge stdClass  stdMarks stdGrades
# 0   Mohit      15        X        98         A
# 1   Ronit      15        X        96         A
# 2   Rohit      17      XII        63         B
# 3   Sonit      17      XII        62         B
