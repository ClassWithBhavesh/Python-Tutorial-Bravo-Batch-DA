# %% [markdown]
# ### ***Targeting specific record or data in Pandas***

# %%
import pandas as pd

# %%
# ds = pd.read_csv("product_data.csv")
# df = pd.DataFrame(ds)

df = pd.DataFrame(pd.read_csv("product_data.csv"))
df

# print(df.loc[49995, 'category'])
# print(df.iloc[49995, 1])

# df.loc[2, 'color']   # .loc[index(int), columnName(string)]
# df.iloc[2, 2]      # .iloc[index(int), index(int)]
# Out:
# Bottoms
# Bottoms

# %% [markdown]
# # ***Handling Misisng and Null Values in Pandas***

# %%
# type(df['color'][5])

df_copy = df.copy()  # it will create a shallow copy of original df
print(df)
print(df_copy)
# Out:
#       product_id     category   color size  season   supplier  cost_price  \
# 0        P000001      Bottoms   Black   XL  Spring  supplierb       78.26
# 1        P000002          ???   Black    M  Summer  supplierc       39.67
# 2        P000003         Tops   Black   XL  Summer  supplierd       27.62
# 3        P000004  Accessories   White   XL  Winter  supplierb        7.43
# 4        P000005  Accessories     NaN   XL    Fall  suppliera       12.04
# ...          ...          ...     ...  ...     ...        ...         ...
# 49995    P049996      Bottoms  Yellow   XS  Winter  supplierc        6.86
# 49996    P049997  Accessories   White    S    Fall  supplierb       30.51
# 49997    P049998      Dresses   White    L  Spring  suppliera       70.61
# 49998    P049999         Tops     Red    L  Winter  suppliera       72.73
# 49999    P050000      Dresses    Blue   XL  Spring  supplierb       25.73
#
#        list_price
# 0           46.45
# 1          147.82
# 2           44.40
# ...

# %%
# provide a new dataframe with 20% increment in cost_price
df_copy['cost_price'] = df_copy['cost_price'] * 1.20

# df_copy
# df
# Out:
#       product_id     category   color size  season   supplier  cost_price  \
# 0        P000001      Bottoms   Black   XL  Spring  supplierb       78.26
# 1        P000002          ???   Black    M  Summer  supplierc       39.67
# 2        P000003         Tops   Black   XL  Summer  supplierd       27.62
# 3        P000004  Accessories   White   XL  Winter  supplierb        7.43
# 4        P000005  Accessories     NaN   XL    Fall  suppliera       12.04
# ...          ...          ...     ...  ...     ...        ...         ...
# 49995    P049996      Bottoms  Yellow   XS  Winter  supplierc        6.86
# 49996    P049997  Accessories   White    S    Fall  supplierb       30.51
# 49997    P049998      Dresses   White    L  Spring  suppliera       70.61
# 49998    P049999         Tops     Red    L  Winter  suppliera       72.73
# 49999    P050000      Dresses    Blue   XL  Spring  supplierb       25.73
#
#        list_price
# 0           46.45
# 1          147.82
# 2           44.40
# ...

# %%
df_copy
# Out:
#       product_id     category   color size  season   supplier  cost_price  \
# 0        P000001      Bottoms   Black   XL  Spring  supplierb    112.6944
# 1        P000002          ???   Black    M  Summer  supplierc     57.1248
# 2        P000003         Tops   Black   XL  Summer  supplierd     39.7728
# 3        P000004  Accessories   White   XL  Winter  supplierb     10.6992
# 4        P000005  Accessories     NaN   XL    Fall  suppliera     17.3376
# ...          ...          ...     ...  ...     ...        ...         ...
# 49995    P049996      Bottoms  Yellow   XS  Winter  supplierc      9.8784
# 49996    P049997  Accessories   White    S    Fall  supplierb     43.9344
# 49997    P049998      Dresses   White    L  Spring  suppliera    101.6784
# 49998    P049999         Tops     Red    L  Winter  suppliera    104.7312
# 49999    P050000      Dresses    Blue   XL  Spring  supplierb     37.0512
#
#        list_price
# 0           46.45
# 1          147.82
# 2           44.40
# ...

# %%
df_copy
# Out:
#       product_id     category   color size  season   supplier  cost_price  \
# 0        P000001      Bottoms   Black   XL  Spring  supplierb    112.6944
# 1        P000002          ???   Black    M  Summer  supplierc     57.1248
# 2        P000003         Tops   Black   XL  Summer  supplierd     39.7728
# 3        P000004  Accessories   White   XL  Winter  supplierb     10.6992
# 4        P000005  Accessories     NaN   XL    Fall  suppliera     17.3376
# ...          ...          ...     ...  ...     ...        ...         ...
# 49995    P049996      Bottoms  Yellow   XS  Winter  supplierc      9.8784
# 49996    P049997  Accessories   White    S    Fall  supplierb     43.9344
# 49997    P049998      Dresses   White    L  Spring  suppliera    101.6784
# 49998    P049999         Tops     Red    L  Winter  suppliera    104.7312
# 49999    P050000      Dresses    Blue   XL  Spring  supplierb     37.0512
#
#        list_price
# 0           46.45
# 1          147.82
# 2           44.40
# ...

# %%
# indentifying the missing and null values

df_copy.isnull().sum()
# Out:
# product_id      0
# category        0
# color         990
# size            0
# season          0
# supplier        0
# cost_price      0
# list_price      0
# dtype: int64

# %%
df1 = pd.DataFrame(pd.read_csv("sales_data.csv"))
df1
# Out:
#       transaction_id        date product_id store_id customer_id  quantity  \
# 0           T0000001  2023-08-02    P004681     S004     C010043         3
# 1           T0000002  2020-08-16    P006662     S003     C022472         1
# 2           T0000003  2020-02-21    P043402     S005     C016135         4
# 3           T0000004  2024-02-27    P029875     S003     C005605         3
# 4           T0000005  2021-07-17    P002476     S003     C005857         4
# ...              ...         ...        ...      ...         ...       ...
# 49995       T0049996  2024-06-30    P044628     S005     C017672         4
# 49996       T0049997  2023-10-08    P007583     S003     C006765         3
# 49997       T0049998  2021-09-30    P026360     S003     C001469         2
# 49998       T0049999  2024-06-13    P033313     S004     C020997         1
# 49999       T0050000  2021-03-19    P026896     S001     C012674         3
#
#        discount  returned
# 0           0.0         0
# ...

# %%
# finding null or nan values in df1 (sales_data.csv)
df1.isnull().sum()

df2 = df1.copy()
df2.isnull().sum()
# Out:
# transaction_id       0
# date                 0
# product_id           0
# store_id             0
# customer_id       1844
# quantity             0
# discount          2583
# returned             0
# dtype: int64

# %%
# Removing missing or null values - using dropna

# df2.dropna(inplace=True)
# print(df2.isnull().sum())
# print(newDf2.isnull().sum())
# Out:
# transaction_id    0
# date              0
# product_id        0
# store_id          0
# customer_id       0
# quantity          0
# discount          0
# returned          0
# dtype: int64
#        transaction_id   date  product_id  store_id  customer_id  quantity  \
# 0               False  False       False     False        False     False
# 1               False  False       False     False        False     False
# 2               False  False       False     False        False     False
# 4               False  False       False     False        False     False
# 5               False  False       False     False        False     False
# ...               ...    ...         ...       ...          ...       ...
# 49995           False  False       False     False        False     False
# 49996           False  False       False     False        False     False
# 49997           False  False       False     False        False     False
# ...

# %%
df_copy.isnull().sum()
# replacing the missing and null values from the dataframe to a default value

# default color is "Magenta"

df_copy.fillna("Magenta", inplace=True)   # if inplace=True then it will return a org DF | that means org DF affected
df_default = df_copy.fillna("Magenta")    # if inplace=False then it will return a new DF | default is FALSE

df_copy.isnull().sum()
df_default.isnull().sum()
# Out:
# product_id    0
# category      0
# color         0
# size          0
# season        0
# supplier      0
# cost_price    0
# list_price    0
# dtype: int64
