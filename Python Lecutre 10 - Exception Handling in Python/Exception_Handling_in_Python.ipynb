# %%
# Exception Handling -
# num = 10
# try:
#   if num <= 10
#   print(num)
# except SyntaxError:
#   print("You can't code like this in python, put a ':' after if statment")


# num = 10
# code = """
# if num <= 10
#   print(num)
# """

# try:
#   exec(code)
# except SyntaxError:
#   print("You can't code like this in python, put a ':' after if statment")

# divisor = int(input("Enter a Number to divide - "))
# try
#   print(4/divisor)
# except ZeroDivisionError:
#   print("please provide a number except of 0, coz nothing can be divided by zero", divisor)
#   print(f"please provide a number except of 0, coz nothing can be divided by zero {divisor}")
# except SyntaxError:
#   print("Please use a ':' after every try block")    # we can't perform exception handling over here coz of SyntaxError



test_code = """
  print(4/divisor)
except ZeroDivisionError:
  print("please provide a number except of 0, coz nothing can be divided by zero", divisor)
  print(f"please provide a number except of 0, coz nothing can be divided by zero {divisor}")
"""

# try:
#   exec(test_code)
#   fileSystem = open("C:/Program Files/HP/filePath.json")
# except SyntaxError:
#   print("Please use a ':' after every try block")
# finally:
#   fileSystem.close()
# Out:
# Please use a ':' after every try block
