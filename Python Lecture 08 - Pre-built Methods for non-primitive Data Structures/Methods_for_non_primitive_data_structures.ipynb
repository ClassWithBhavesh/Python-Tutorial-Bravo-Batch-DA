# %%
# Data Structures in Python -
# Non-Primitive -
# LIST
# SET
# TUPLE
# DICTIONARY

# %%
# List -
# - in python is a well-defined collection of items which are in ordered sequence and are changeable (mutable)
# - list will be declared only using square braces ("[]")
# - list items has some unique identity which will be known as index value (0 - len-1)

# carCollect = ["Fortuner", "Range Rover", "Endeavour", "Scorpio", "Defender"]
# print(carCollect)
# print(type(carCollect))
# print(len(carCollect))
# print(carCollect[0])

# for cars in carCollect:
#   print(cars)

# print(carCollect)
# print(carCollect[1])
# carCollect[1] = "XUV"
# print(carCollect[1])
# print(carCollect)
# Out:
# ['Fortuner', 'Range Rover', 'Endeavour', 'Scorpio', 'Defender']
# ['Fortuner', 'XUV', 'Endeavour', 'Scorpio', 'Defender']

# %%
# Tuples -
# - in python is a well-defined collection of items which are in ordered sequence and are non-changeable (im-mutable)
# - denoted by ("()")
# - yes, having index values

# editorial = ("The Hindus", "Hindustan Times", "Editorial Express", "Word Wise Editorial")
# print(editorial)
# you have to change "Hindustan Times" to "The Indian Express" in the provided tuple.

# type-casting - is method or procedure in which we will convert the data types of variables
# edit_li = list(editorial)

# edit_li[1] = "The Indian Express"

# editorial = tuple(edit_li)
# print(editorial)


# "" - Double inverted commas
# '' - Inverted Commas
# print(editorial)
# print(type(editorial))

# print(editorial[0])
# print(editorial[1])
# print(editorial[2])
# print(editorial[3])

# print(editorial)
# editorial[0] = "The Indian Express"
# print(editorial)

# %%
# Dictionary -
# - well defined mutable collection of items in the form of key-value pair
# - denoted by ("{}")
# - doesn't have any index values but having keys that means the keys should be unique
# - duplicate keys will not be allowed in dictionary
# - it is a ordered collection

# offical syntax of dictionary -
# dict = {
    # "keys": "Values"
# }

# carDict = {
#     "carCpyName": "Land Rover",
#     "carName": "Range Rover",
#     "carModel": "Velar"
# }

# print(carDict)

# print(carDict["carName"])
# print(carDict["carModel"])


# carDict = {
#     "carCpyName": ("Mahindra", "Land Rover", "Mahindra", "Mercedes", "Jeep"),
#     "carName": ["Thar", "Range Rover", "Scorpio", "G-Wagon", "Compass"],
#     "carModel": ["ROX 4x4", "Velar", "S-11", "G-550", "Model-S"]
# }

# print(carDict)

# print(carDict['carName'][3])
# print(carDict['carName'])
# print(carDict['carCpyName'])

# %%
# Set -
# - unordered collection of data
# - doesn't have any index value coz of unordered behavour
# - denoted by ("{}")
# - immutable

# set_declared = {10,20,50,30}
# set_declared
# type(set_declared)

# %%
# List Methods in Python for more and easy Data Manipulation -

# %%
# IoT_Temp_d1 = [21.6, 54.3, 32.5, 21.3, 23.4]
# print(IoT_Temp_d1)

# IoT_Sensor_Temp_day2 = [23.6, 24.3, 22.2, 23.3, 13.4]
# print(IoT_Sensor_Temp_day2)

# merged_IoT_Data = IoT_Sensor_Temp_day1 + IoT_Sensor_Temp_day2
# print(merged_IoT_Data)

# indexing
# IoT_Sensor_Temp[1] = 22.6
# print(IoT_Sensor_Temp)


# 1. sort - it will sort each element of list (default - ascending and if reverse argument is used then descending)
# li_name.sort()

# print("before sorting : ", IoT_Temp_d1)
# IoT_Temp_d1.sort()
# print("after sorting : ",IoT_Temp_d1)

# IoT_Temp_d1.sort(reverse=True)
# print("after reverse sorting : ",IoT_Temp_d1)



# 2. .append()
# IoT_Temp_d1 = [21.6, 54.3, 32.5, 21.3, 23.4]
# print("Before Appending : ", IoT_Temp_d1)

# another_value = 24.6
# IoT_Temp_d1.append(24.6)
# another_list = [24.6, 23.8, 27.5]
# IoT_Temp_d1.append(another_list)
# print("After Appending : ", IoT_Temp_d1)

# IoT_Temp_d1.append(24.6, 25.3, 21.5) # using this code we'll encounter with an typeError coz .append method will expect only single argument


# 2. .extend()
# IoT_Temp_d1 = [21.6, 54.3, 32.5, 21.3, 23.4]
# print("Before Extending : ", IoT_Temp_d1)

# another_list = [24.6, 23.5, 25.1]
# # IoT_Temp_d1.extend([24.6])
# IoT_Temp_d1.extend(another_list)
# print("After Extending : ", IoT_Temp_d1)



# 3. .insert() - it will insert the value on our desired index value
# IoT_Temp_d1 = [21.6, 54.3, 32.5, 21.3, 23.4]
# print("Before Inserting : ", IoT_Temp_d1)

# IoT_Temp_d1.insert(index, value)
# IoT_Temp_d1.insert(2, 24.3, 21.6, 23.9)
# IoT_Temp_d1.insert(2, [24.3, 21.6, 23.9])
# print("After Inserting : ", IoT_Temp_d1)



# 4. .remove(value) - it will remove the argumented value from the list
# IoT_Temp_d1 = [21.6, 54.3, 32.5, 21.3, 23.4]
# print("Before Removing : ", IoT_Temp_d1)

# IoT_Temp_d1.remove(value)
# IoT_Temp_d1.remove(21.3)
# IoT_Temp_d1.remove(21.3, 21.6)
# IoT_Temp_d1.insert(2, [24.3, 21.6, 23.9])
# print("After Removing : ", IoT_Temp_d1)



# 5. .pop(index) - it will remove the argumented value from the list on the basis of indexes (default it will remove the end value)
# IoT_Temp_d1 = [21.6, 54.3, 32.5, 21.3, 23.4]
# print("Before Poping : ", IoT_Temp_d1)

# IoT_Temp_d1.pop(index=?)
# IoT_Temp_d1.pop(1)
# IoT_Temp_d1.pop()
# IoT_Temp_d1.remove(21.3, 21.6)
# IoT_Temp_d1.insert(2, [24.3, 21.6, 23.9])
# print("After Poping : ", IoT_Temp_d1)




# 6. .clear() - it will clear the list (all elements will be removed and return an empty list)
# IoT_Temp_d1 = [21.6, 54.3, 32.5, 21.3, 23.4]
# print("Before Clearing : ", IoT_Temp_d1)

# IoT_Temp_d1.clear()
# print("After Clearing : ", IoT_Temp_d1)




# 7. index(value, start=, end)
# IoT_Temp_d1 = [21.6, 54.3, 32.5, 54.3, 21.3, 54.3, 23.4]
# print("Before Indexing : ", IoT_Temp_d1)

# print("index of 54.3 - ", IoT_Temp_d1.index(54.3))
# print("index of 23.4 - ", IoT_Temp_d1.index(23.4))
# print("index of 54.3 - ", IoT_Temp_d1.index(54.3, 3, 5))
# print("After Indexing : ", IoT_Temp_d1)




# 8. .count()
# IoT_Temp_d1 = [21.6, 54.3, 32.5, 54.3, 21.3, 54.3, 23.4]
# print("Before Indexing : ", IoT_Temp_d1)

# IoT_Data_Count = IoT_Temp_d1.count(21.3)
# print("21.3 Repeat count : ", IoT_Data_Count)
# IoT_Data_Count = IoT_Temp_d1.count(54.3)
# print("21.3 Repeat count : ", IoT_Data_Count)


# 9. .reverse()
# IoT_Temp_d1 = [21.6, 54.3, 32.5, 54.3, 21.3, 54.3, 23.4]

# print("Before Reversing : ", IoT_Temp_d1)
# IoT_Temp_d1.reverse()
# print("After Reversing : ", IoT_Temp_d1)



# 10. .copy() - It will create a copy of a list
# IoT_Temp_d1 = [21.6, 54.3, 32.5, 54.3, 21.3, 54.3, 23.4]
# print("Before Copying : ", IoT_Temp_d1)

# copied_list = IoT_Temp_d1.copy()
# print("After Copying : ", copied_list)
# copied_list.pop(3)
# print("Before Copying : ", IoT_Temp_d1)
# print("After Copying : ", copied_list)

# %%
# tuple Methods - due to immutability tuple doesn't have bunch of methods. it has only two methods which are in the following -
# 1. .count()
# 2. .index()


# 1. .count(Value)
# bikeTuple = ("Splendar", "CD-Deluxe", "Freedom", "CD-Deluxe", "Boxer", "CD-Deluxe", "RX-110")
# print(bikeTuple.count("CD-Deluxe"))


# 2. .index(Value)
# akProOrders = ("Micchar","Sev", "Micchar", "Aloo Bhujiya", "Micchar", "Chips")
# print(akProOrders.index("Micchar"))

# %%
# Set Methods in Python -

# 1..add(element)
# ex-1
# customers = {101, 102, 103}
# print(customers)
# customers.add(104)
# print(customers)

# ex-2
# categories = {"Electronics", "Clothing"}
# print(categories)
# categories.add("Furniture")
# print(categories)



# 2. setName.clear()
# tags = {"Sale", "Trending", "Refurbished"}
# print(tags)
# tags.clear()
# print(tags)


# build_set = {}
# print(type(build_set))   # return empty dictionary

# build_set = set()
# print(type(build_set))   # return empty set




# 3. .copy()
# s1 = {1, 2, 3}
# s2 = s1.copy()
# print(s2)
# print(s1)

# s1.add("KuchBhi")
# print(s2)
# print(s1)


# Shallow Copy - a ditto copy of the first set but dependent on the first set
# Deep Copy    - a ditto copy of the first set but in-dependent of the first set



# 4. .difference(newSet)
# setA = {"Mobile", "Laptop", "Tablet"}
# print(setA)
# setB = {"Laptop", "Camera"}
# print(setB)
# print("different value of set A", setA.difference(setB))
# print("different value of set B", setB.difference(setA))



# 5. .difference_update(newSet) - it will remove the founded value
# setA = {"Mobile", "Laptop", "Tablet"}
# print(setA)
# setB = {"Laptop", "Camera"}
# print(setB)
# print("different value of set A", setA.difference_update(setB))
# print("different value of set B", setB.difference_update(setA))


# A = {1,2,3,4}
# B = {3,4}
# A.difference_update(B)
# print(A)


# 6. discard(element) - it will remove the element by the correct argument
# cart = {"Shoes","Watch","Belt"}
# print(cart)
# unavailable = "Belt"
# cart.discard(unavailable)
# print(cart)
# cart.discard("Watch")
# print(cart)



# 7. intersection(other_set) - it will return the common value between the two sets
# skills = {"Python","SQL", "Go"}
# print(skills)
# job = {"Python","Java", "Kotlin", "Go"}
# print(job)
# print(skills.intersection(job))


# 8. intersection_update(other_set) - it will return the common value between the two sets
# skills = {"Python","SQL","Excel"}
# print(skills)
# required = {"Python","SQL"}
# print(required)
# print(skills.intersection_update(required))


# A = {1,2,3}
# B = {2,3}
# A.intersection_update(B)
# print(A)


# 9. .isdisjoint(other_set)
# A = {1,2}
# B = {3,4}
# print(A.isdisjoint(B))

# A = {1,2, 3, 4}
# B = {3,4}
# print(A.isdisjoint(B))


# employees = {"Rahul","Amit", "Manoj"}
# guests = {"Suresh","Manoj"}
# print(employees.isdisjoint(guests))




# 10. .subset(other_set) -
# req = {"Python", "JavaScript"}
# dev = {"Python","SQL", "JavaScript", "PhP"}
# print("Subset Checks - ")
# print(req.issubset(dev))
# print(dev.issubset(req))



# 11. .superset(other_set) -
# req = {"Python", "JavaScript"}
# dev = {"Python","SQL", "JavaScript", "PhP"}
# print("Superset Checks - ")
# print(req.issuperset(dev))
# print(dev.issuperset(req))



# 12. .pop() -
# s = {1,2,3}
# print(s)
# print(s.pop())
# print(s)



# 13. remove(Element)
# s = {1,2,3}
# print(s)
# s.remove(3)  # simply remove the element
# s.remove(7)  # throws an error
# print(s)



# 14. symmetric_difference
# A = {1,2}
# B = {2,3}
# print(A)
# print(B)
# print(A.symmetric_difference(B))
# print(A)
# print(B)





# 15. .symmetric_difference_update(other_set)
# A = {1,2, 3}
# B = {2,3, 1}
# print(A.symmetric_difference_update(B))

# x = {"A","B"}
# y = {"B","C"}
# print(x)
# print(y)
# print(x.symmetric_difference_update(y))
# print(x)
# print(y)



# 16. union(otdet_set)
# skills = {"Python", "Java"}
# extra = {"SQL","Java"}
# new_set = skills.union(extra)
# print(new_set)




# 17. .update(Other_set) - '+='
# skills = {"Python"}
# print(skills)
# skills.update({"SQL","Java"})
# print(skills)


# A = {1,2}
# print(A)
# B = {3,4}
# A.update(B)
# print(A)
# Out:
# {1, 2}
# {1, 2, 3, 4}
