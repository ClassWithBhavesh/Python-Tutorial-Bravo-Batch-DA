# %%
# Functions in Python -
# What is Function?
# - function is just a bunch of code which will perform certain operations
# - we can execute a function in two steps
    # 1. Function Declaration
    # 2. Function Calling     ---> func_name()
# - it will reduce the complexity of the code and increase the reusability of the code



# num1 = 15
# num2 = 26

# print(num1 + num2)

# num1 = 45
# num2 = 23

# print(num1 + num2)

# parameters - that is assigned at the time of function declaration
# def sum_func(num1, num2, num3, num4):   # function declaration
#   print(num1 + num2 + num3 + num4)

# sum_func(42, 28, 87, 75) # arguments - that is assign at the time of function calling

# if, for, while, def, class, List, Set, Dict, Tuple

# def sub_func(num1, num2, num3):
#   print(num1 - num2 - num3)

# sub_func(100, 50, 25)
# sub_func(10, 40, 45)
# sub_func(14, 540, 15)
# sub_func(17, 510, 65)
# sub_func(17, 510, 65)
# sub_func(17, 510, 65)
# sub_func(17, 510, 65)
# sub_func(17, 510, 65)
# sub_func(17, 510, 65)
# sub_func(17, 510, 65)


# function types -
  # 1. Standard function
  # 2. Parametric Function
  # 3. function with returned value




# def - function declare karne ke liye
# function name likhna hota hai
# paranthesis - parameters | agar nahi dena hai mat do(it is not mandotory to provide parameters to each and every functions)
# colon - : is must

# 1. Standard Function -
# def function_name(para1, para2, ....):
#   function ki body

# def show_msg():
#     print("Hello from Python")


# 2. Parametric Function - jiske andar parameters pass kiye jate hai
# def multi_func(num1, num2):
#     print(num1 * num2)


# show_msg()
# multi_func(10, 20)



# 3. function with returned values -

# def add_func(num1, num2):
#     result = num1 + num2
#     print(result)
# print("upar wala function")
# add_func(10, 20)

# -------------------------------------------

# def add_func(num1, num2):
#     # result = num1 - num2
#     return num1 - num2

# print("niche wala function")
# result = add_func(10, 20)
# print(result)

# print(45 + 85)
# 45 + 85

# %%
# Recursion in Python - when a function call itself within that same function to perform some operation than it will be known as recursion

# %%
# def sum(n1, n2):
#   result = n1 + n2
#   if result <= 100:       # base case - to stop the recursion
#     print(result)
#     sum(n1 + 1,n2 + 2)
#   else:
#     print("Recurison Ended Here!")

# sum(1,2)

# %%
# Factorial -

# def fact(n):
#   if n == 1:
#     return 1
#   else:
#     return n * fact(n-1)


# factorial = fact(5)
# factorial

# %%
# H.W. - write a python program to print a fibonacci series for nth value. the input must be taken from user

# %%
user_inp = int(input("Enter a number - "))

def fibo(inp):
  if inp <= 1:
    return inp
  return fibo(inp - 1) + fibo(inp - 2)

fibo_num = fibo(user_inp)
fibo_num
# Out:
# Enter a number - 8
# 21
