# %% [markdown]
# ### ***NumPy Introduction***

# %%
arr = [10, True, "abhi", 12.78]
print(arr)

li = [10,20,30,50,40]
print(type(li))
# Out:
# [10, True, 'abhi', 12.78]
# <class 'list'>
# <class 'numpy.ndarray'>

# %%
# pip install pandas

# %%
# pip install numpy

# %% [markdown]
# # ***Creating a NumPy Array***

# %%
# pre-built methods -
# Slicing - these are the pieces of Array

# %%
import numpy as np

arr1 = np.array([10,20,30,60,45,12,78,95])

# np.shape() - it will return the shape of the provided matrix ya array
# np.shape(arr1)

# np.ndim() - it will return the nth dimension in which array lies
# np.ndim(arr1)

# np.linspace() - it will retun a evenly divide sequence through the (start, end, required division)
# int_arr = np.linspace(start, end, required even division)
#
# int_arr = np.linspace(1, 5, 5)
# int_arr

# int_arr.shape
# np.shape(int_arr)
# int_arr

# ---> hommbak - find out the way to type cast the array elements!
# ---> hommbak - write a program to find whether the given nth number is a ArmStrong(BahuBali) number or not!
# ---> hommbak - Write a Program to find whether the given input is a Strong number or not

# %%
# find whether the given input (no. of digits - 3) is a armstrong number or not!
# 153
# 1**3  +   5**3  +  3**3    --->    153

# 153 == 153   ----->  Armstrong Numbers

userNum = int(input("Enter a 3-digit number only - "))
# to find the number of digits
tempNum = userNum
outNum = 0
for i in range(1, 4):
  num = 0
  single_num = tempNum % 10
  num = single_num ** 3
  outNum += num      # outnum = outnum +
  tempNum //= 10     # tempNum = tempNum // 10

if outNum == userNum:
  print(f"{userNum} is a ArmStrong (Bahubali) Number!")
else:
  print(f"{userNum} is not a ArmStrong (BhallalDev) Number!")
# Out:
# Enter a 3-digit number only - 568
# 568 is not a ArmStrong (BhallalDev) Number!
