# %% [markdown]
# ### ***pre-buil methods to manipulate NumPy Array***

# %%
import numpy as np

# %%
# np.zeros
# np.ones
# np.full
# np.eye
# np.indentity

# arr = np.arange(1,13).reshape(3,4)
# print(arr)

# iMatrix = np.eye(4,3)      # Indentity Matrix
# print(iMatrix)

# iMatrix = np.identity(2)      # Identity Matrix
# print(iMatrix)



# random methods - it will help us to generate a random array
# randomArr = np.random.rand(7)     # (0 to 1)*100
# randomArr = np.random.rand(7)*10   # 0 to 10
# randomArr = np.random.rand(7)*100   # 0 to 100
# print(randomArr)
# randomArr = np.random.rand(2,3)*100   # 0 to 100
# print(randomArr)
# randomArr = np.random.rand(2,3,4)*100   # 0 to 100
# print(randomArr)

# randIntArr = randomArr.astype(np.int64)
# print(randIntArr)


# np.randn()
# arr = np.random.randn(5)
# print(arr)
# rest demostration, student's will try and code


# np.randint()
# intArr = np.random.randint(1, 15, size=[2,3,4])
# print(intArr)
# Out:
# [[[ 8 12  9  7]
#   [ 9 12 11  4]
#   [ 9  8  6 14]]
#
#  [[ 8 10  1 14]
#   [ 6  3  1  4]
#   [ 2  3  5  7]]]

# %%
# Agregation Methods - it will help us to provide a statistical summary of an Array

# arr = np.array([1,5,7,8,9,6,3,2])
# print(arr)
# sumOfArr = np.sum(arr)
# print(sumOfArr)


# li = [1,2,3,4]
# ekorli = [5,6,7,8]
# print(li + ekorli)


arrli = np.array([1,2,3,4])
arrekorli = np.array([5,6,7,8])
# # print(arrli + arrekorli)
# # newArr = np.sum(arrli + arrekorli)
# newArr = np.sum([arrli, arrekorli])
# print(newArr)

# concatedArr = np.concatenate([arrli, arrekorli])
# concatedArr = np.concatenate((arrli, arrekorli))
# print(concatedArr)


# minValue = np.min(arrli)
# print(minValue)

# minValue = np.max(arrekorli)
# print(minValue)

# meanValue = np.mean(arrli)
# print(meanValue)
# meanValue = np.average(arrli)
# print(meanValue)
# meanValue = np.median(arrli)
# print(meanValue)
# Out:
# 12.0

# %% [markdown]
# # ***Broadcasting & Vectorization in NumPy***

# %%
# proPrice = np.array([200, 2500, 3200, 900])
# print(proPrice)
# type(proPrice)

# proPriceLi = proPrice.tolist()
# print(proPriceLi)
# type(proPriceLi)
# dis_price = []

# discounted price -
# for price in proPriceLi:
#   disPrice = price * 30 / 100
#   dis_price.append(disPrice)

# print(dis_price)

# final price  -
# fin_price = []
# for price in proPriceLi:
  # disPrice = (price * 1.3) - price      # -->   100 * 1.3  =  130
  # disPrice = price * 0.3                # -->   100 * 0.3  =  30   --->    100 * 30 / 100
  # finPrice = price * 70/100             # -->   100 * 0.7  =  70
  # finPrice = price * 0.7                # -->   100 * 0.7  =  70
  # fin_price.append(finPrice)

# print(fin_price)
# let us provide a discount of 30% on each provide - and find discounted price and final price
# 100₹
# -30₹   ---> Discounted Price
#  70₹   ---> Final Price  |  After Discount Price

# %%
proPrice = np.array([200, 2500, 3200, 900])

# discounted price array -
dis_price_arr = proPrice * 0.3                  #  ---> [200, 2500, 3200, 900] * 0.3   --> Broadcasting - operation apply hoga array pr
print(f"discounted array - {dis_price_arr}")
fin_price_arr = proPrice - (proPrice * 0.3)     #  ---> [200, 2500, 3200, 900] - [60, 750, 960, 270]
print(f"Final array - {fin_price_arr}")         #  ---> [140, 1750, 2240, 630]
# Out:
# discounted array - [ 60. 750. 960. 270.]
# Final array - [ 140. 1750. 2240.  630.]
